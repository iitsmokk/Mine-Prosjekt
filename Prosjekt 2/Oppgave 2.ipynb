# %% [markdown]
# Importerer de samme bibliotekene som be brukt i Oppgave 1) Siden denne oppgaven går ut på litt av det samme
# Mye av denne koden kommer til å bruke linjer fra Oppgave 1) så er ikke like nøye på
# å oppgi hva som skjer memindre det er noe nytt fra Oppgave 1)

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Oppgave 2 a)

# %%
np.linspace(0,20,10)
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])
